# %%
import sys
import os
sys.path.append(os.path.abspath('../../lib')) 

import sources

# %%
df = sources.ingest_world_bank("NY.GDP.MKTP.CD")

# %%
df.reset_index()
# Out:
#       country  year             0
# 0         ABW  1960           NaN
# 1         ABW  1961           NaN
# 2         ABW  1962           NaN
# 3         ABW  1963           NaN
# 4         ABW  1964           NaN
# 5         ABW  1965           NaN
# 6         ABW  1966           NaN
# 7         ABW  1967           NaN
# 8         ABW  1968           NaN
# 9         ABW  1969           NaN
# 10        ABW  1970           NaN
# 11        ABW  1971           NaN
# 12        ABW  1972           NaN
# 13        ABW  1973           NaN
# 14        ABW  1974           NaN
# 15        ABW  1975           NaN
# 16        ABW  1976           NaN
# 17        ABW  1977           NaN
# 18        ABW  1978           NaN
# 19        ABW  1979           NaN
# 20        ABW  1980           NaN
# 21        ABW  1981           NaN
# 22        ABW  1982           NaN
# 23        ABW  1983           NaN
# 24        ABW  1984           NaN
# 25        ABW  1985           NaN
# ...

# %%
"as.asd.as".replace(".","_")
# Out:
# 'as_asd_as'
